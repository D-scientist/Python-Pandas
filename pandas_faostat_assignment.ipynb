# %% [markdown]
# # FAO STAT

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("FAOSTAT_data_2-2-2022.csv")
df.head(5)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6127   Value      21030
# 1          6127   Value      21030
# 2          6127   Value      21030
# 3          6127   Value      21030
# 4          6127   Value      21030
#
#                                                 Item  Year Code  Year  \
# 0  Per capita food production variability (consta...       2001  2001
# 1  Per capita food production variability (consta...       2002  2002
# 2  Per capita food production variability (consta...       2003  2003
# ...

# %%
df.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count       17.0          17.0       17.0    17.000000    17.000000
# mean       165.0        6127.0    21030.0  2009.000000  2009.000000
# std          0.0           0.0        0.0     5.049752     5.049752
# min        165.0        6127.0    21030.0  2001.000000  2001.000000
# 25%        165.0        6127.0    21030.0  2005.000000  2005.000000
# 50%        165.0        6127.0    21030.0  2009.000000  2009.000000
# 75%        165.0        6127.0    21030.0  2013.000000  2013.000000
# max        165.0        6127.0    21030.0  2017.000000  2017.000000
#
#            Value  Note
# count  17.000000   0.0
# mean    3.841176   NaN
# std     1.104569   NaN
# min     1.800000   NaN
# 25%     3.300000   NaN
# 50%     3.700000   NaN
# 75%     4.100000   NaN
# max     6.500000   NaN

# %%
new_df=df.drop(["Flag","Flag Description","Note"],axis=1)
new_df.head(5)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6127   Value      21030
# 1          6127   Value      21030
# 2          6127   Value      21030
# 3          6127   Value      21030
# 4          6127   Value      21030
#
#                                                 Item  Year Code  Year  \
# 0  Per capita food production variability (consta...       2001  2001
# 1  Per capita food production variability (consta...       2002  2002
# 2  Per capita food production variability (consta...       2003  2003
# ...

# %%
new_df.mean()
# Out:
# C:\Users\M6205~1.TAN\AppData\Local\Temp/ipykernel_3440/3764789720.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.mean()
# Area Code         165.000000
# Element Code     6127.000000
# Item Code       21030.000000
# Year Code        2009.000000
# Year             2009.000000
# Value               3.841176
# dtype: float64

# %%
new_df.groupby(["Year","Value"]).mean()
# Out:
#             Area Code  Element Code  Item Code  Year Code
# Year Value
# 2001 1.8        165.0        6127.0    21030.0     2001.0
# 2002 4.9        165.0        6127.0    21030.0     2002.0
# 2003 6.5        165.0        6127.0    21030.0     2003.0
# 2004 5.7        165.0        6127.0    21030.0     2004.0
# 2005 4.1        165.0        6127.0    21030.0     2005.0
# 2006 3.1        165.0        6127.0    21030.0     2006.0
# 2007 3.6        165.0        6127.0    21030.0     2007.0
# 2008 4.0        165.0        6127.0    21030.0     2008.0
# 2009 4.1        165.0        6127.0    21030.0     2009.0
# 2010 3.3        165.0        6127.0    21030.0     2010.0
# 2011 3.7        165.0        6127.0    21030.0     2011.0
# 2012 3.3        165.0        6127.0    21030.0     2012.0
# 2013 3.8        165.0        6127.0    21030.0     2013.0
# 2014 3.6        165.0        6127.0    21030.0     2014.0
# 2015 3.2        165.0        6127.0    21030.0     2015.0
# ...

# %%
new_df.value_counts('Year Code')
# Out:
# Year Code
# 2001    1
# 2010    1
# 2016    1
# 2015    1
# 2014    1
# 2013    1
# 2012    1
# 2011    1
# 2009    1
# 2002    1
# 2008    1
# 2007    1
# 2006    1
# 2005    1
# 2004    1
# 2003    1
# 2017    1
# dtype: int64

# %%
new_df[new_df["Year"]>2008].groupby(["Value","Item Code"]).mean()
# Out:
#                  Area Code  Element Code  Year Code    Year
# Value Item Code
# 2.5   21030          165.0        6127.0     2016.0  2016.0
# 3.2   21030          165.0        6127.0     2015.0  2015.0
# 3.3   21030          165.0        6127.0     2011.0  2011.0
# 3.6   21030          165.0        6127.0     2014.0  2014.0
# 3.7   21030          165.0        6127.0     2011.0  2011.0
# 3.8   21030          165.0        6127.0     2013.0  2013.0
# 4.1   21030          165.0        6127.0     2013.0  2013.0
